# %% [markdown]
# # Projet Tehniques de Sondage
#
# # Membre du groupe:
#
# # Lassana Ba
# # Ismael YODA
# # Souhoude Ouedraogo

# %% [markdown]
# ## EXERCICE 1
#
# Probabilité d'inlusion. Soit la p opulation {1, 2, 3} et le plan de sondage suivant :
# #### $\mathbf{P}(\{1,2\})=\frac{1}{2} \quad \mathbf{P}(\{1,3\})=\frac{1}{4} \quad \mathbf{P}(\{2,3\})=\frac{1}{4}$
#
# 1. Ce sondage n'est pas un sondage aleatoire simple, les echantillons n'ont pas les memes chances d'etre tirer, c'est le cas de l’échantillon {1, 2} qui a plus de chances d’apparaître que les autres.
#
# 2. Calulons $\pi_{1}, \pi_{2}, \pi_{3}$, les probabilités d'inlusion d'ordre 1 :
# #### $\mathbf\pi_{1} =\mathbf{P}(\{1,2\})+\mathbf{P}(\{1,3\})=\frac{1}{2}+\frac{1}{4}=\frac{3}{4}$
# #### $\mathbf\pi_{2} =\mathbf{P}(\{1,2\})+\mathbf{P}(\{2,3\})=\frac{1}{2}+\frac{1}{4}=\frac{3}{4}$
# #### $\mathbf\pi_{3} =\mathbf{P}(\{1,3\})+\mathbf{P}(\{2,3\})=\frac{1}{4}+\frac{1}{4}=\frac{1}{2}$
# </br>
# 3. Calulons $\pi_{12}$ , et  $\pi_{23}$ les probabilités d'inlusion d'ordre 2 :
# #### $\mathbf\pi_{12} =\mathbf{P}(\{1,2\})=\frac{1}{2}$
# #### $\mathbf\pi_{23} =\mathbf{P}(\{2,3\})=\frac{1}{4}$
#
# 4. Quel est le $\pi$ -estimateur de $\bar{Y}$ ? Nous noterons $Y_{1}, Y_{2}$ et $Y_{3}$ les vale respectives de la variable $Y$.
#
#
# $\widehat{\bar{Y}}=\frac{1}{N} \sum_{i=1}^{n} \frac{Y_{i}}{\pi_{i}}$
#
#     a) si l'échantillon {1,2} est tiré on a :
# #### $\widehat{\bar{Y}_{1}} = \frac{1}{3}.(\frac{1}{\frac{3}{4}}+\frac{2}{\frac{3}{4}}) = \frac{4}{3} $
#
#     b) si l'échantillon {1,3} est tiré on a :
# #### $\widehat{\bar{Y}_{2}} = \frac{1}{3}.(\frac{1}{\frac{3}{4}}+\frac{3}{\frac{1}{2}}) = \frac{22}{9} $
#
#     c) si l'échantillon {2,3} est tiré on a :
# #### $\widehat{\bar{Y}_{3}} = \frac{1}{3}.(\frac{2}{\frac{3}{4}}+\frac{3}{\frac{1}{2}}) = \frac{26}{9}$
# <br>
#
# 5. Vérifier que le $\pi$ -estimateur est un estimateur sans biais.
#
#     $\mathbf{P}(\widehat{\bar{Y}_{1}})=\mathbf{P}(\{1,2\})= \frac{1}{2}$
#
#     $\mathbf{P}(\widehat{\bar{Y}_{2}})=\mathbf{P}(\{1,3\})= \frac{1}{4}$
#
#     $\mathbf{P}(\widehat{\bar{Y}_{3}})=\mathbf{P}(\{2,3\})= \frac{1}{4}$
#
#     * $\mathbf{E}(\widehat{\bar{Y}})=\frac{1}{2} \frac{4}{3}+\frac{1}{4} \frac{22}{9}+\frac{1}{4} \frac{26}{9}= \frac{12}{6}=2$
#
#      ${\bar{Y}} =\frac{1}{3}(1+2+3)=2$
#
#      On constate que $\mathbf{E}(\widehat{\bar{Y}})= {\bar{Y}}$
#
#     Le $\pi$ estimateur $\widehat{\bar{Y}}$  est donc un estimateur sans biais de ${\bar{Y}}$ .
#
# 6. Les probabilités d'échantillon P et les probabilités d'inclusion $\pi$ si c'etait un sondage aléatoire simple à probabilités égales sans remise sont :
#
#     #### $\mathbf{P}(\{1,2\})= \mathbf{P}(\{1,3\})= \mathbf{P}(\{2,3\}) = \frac{1}{3}$
#     #### $\mathbf\pi_{1} = \mathbf\pi_{2} = \mathbf\pi_{3} = \frac{2}{3}$
#     #### $\mathbf\pi_{12} = \mathbf\pi_{23} = \frac{1}{3}$

# %% [markdown]
# ## EXERCICE 2
#
# 1. La taille d'échantillon qu'il faut selectionner pour que la longueur totale d'un intervalle de confiance avec un niveau de confiance 0.95 soit inférieure à 0.02 pour les plans simples avec et sans remise est la suivante :
#
#     Nous avons la proportion **p** qui a pour expression : $$p=\frac{1}{N} \sum_{i \in \mathcal{U}} y_{i}, \text { comme indicatrice de la presence ou non de la maladie } $$
#
#     l'estimateur et la variance de l'estimateur de **p** sont les suivantes : $$\hat{p}=\frac{1}{n} \sum_{i \in \mathcal{U}} y_{i} 1_{\{i \in S\}}, \quad \operatorname{Var}[\hat{p}]=\left\{\begin{array}{ll}
# \frac{p(1-p)}{n}, & \text { avec remise } \\
# \frac{N-n}{N-1} \frac{p(1-p)}{n}, & \text { sans remise }
# \end{array}\right.$$
#
#     Dans le cas ou nous considerons n suffisamment grande pour que l'on puisse utiliser  l’approximation selon la loi normale, l'intervalle de confiance a 95% se presente comme suite :
#
#     $\left[\hat{p} - 1.96 \times \sqrt{\operatorname{Var}[\hat{p}]},\hat{p} + 1.96 \times \sqrt{\operatorname{Var}[\hat{p}]}\right]$
#
#      la longueur totale de intervalle de confiance : $2 \times 1.96 \times \sqrt{\operatorname{Var}[\hat{p}]} $
#
#      Ainsi,  $2 \times 1.96 \times \sqrt{\operatorname{Var}[\hat{p}]} \leq 0.02 \Longleftrightarrow \operatorname{Var}[\hat{p}] \leq 196^{-2}$
#
#      $$\begin{array}{l}
# \Longleftrightarrow\left\{\begin{array}{ll}
# \frac{p(1-p)}{n} \leq 196^{-2}, & \text {avec remise } \\
# \frac{N-n}{N-1} \frac{p(1-p)}{n} \leq 196^{-2}, & \text {avec remise }
# \end{array}\right. \\
# \Longleftrightarrow\left\{\begin{array}{ll}
# n \geq 196^{2} p(1-p) & \text { avec remise } \\
# n \geq 196^{2} N p(1-p) \quad / \quad (N-1+196^{2} p(1-p)) & \text { sans remise }
# \end{array}\right.\\ \\
# P = \frac{1}{3} \text { et } N = 1500 \\ \\
# \Longleftrightarrow n\geq\left\{\begin{array}{ll}
# 8067, & \text { avec remise } \\
# 1264, & \text { sans remise }
# \end{array}\right.
# \end{array}$$
#
# 2. Si l'on ne connait pas la proportion de personnes affectées, on remplace $\operatorname{Var}[\hat{p}]$ par son estimation :
# $$\widehat{\operatorname{Var}[\hat{p_{AR}}]}=\left\{\begin{array}{ll}
# \frac{\hat{p_{AR}}(1-\hat{p_{AR}})}{n-1}, & \text { avec remise }
# \end{array}\right.$$
#
# $$\widehat{\operatorname{Var}[\hat{p_{SR}}]}=\left\{\begin{array}{ll}
# \frac{\hat{p_{SR}}(1-\hat{p_{SR}})}{n-1}, & \text { avec remise }
# \end{array}\right.$$
#
#
# Une autre approche consisterait à prendre le cas le plus mauvais (ou pessimiste), c'est à dire la valeur théorique de $p$ telle que $\operatorname{Var}[\hat{p}]$ soit la plus grande possible. Clairement le cas le plus pessimiste correspond au choix $p=0.5$

# %% [markdown]
# ## EXERCICE 3

# %% [markdown]
# 1. Au premier dégré on a:
#
#  M = 50 colléges, m = 5 colléges, f1= 0,1.
#
# 2. Au second dégré on a:
#
# $\begin{array}{|c|c|c|c|c|c|}
# \hline \text { Observation } & N_{i} & n_{i} & \bar{y}_{i} & s_{i}^{2} & \widehat{T}_{i} \\
# \hline 1 & 40 & 10 & 12 & 1,5 & 480 \\
# \hline 2 & 20 & 10 & 8 & 1.2 & 160 \\
# \hline 3 & 60 & 10 & 10 & 1.6 & 600 \\
# \hline 4 & 40 & 10 & 12 & 1.3 & 480 \\
# \hline 5 & 48 & 10 & 11 & 2.0 & 528 \\
# \hline \text { Total } & 208 & 50 & & & 2248 \\
# \hline
# \end{array}$
#
#
# Dans chaque collège, on estime la note totale $T_{i}$ par :
#
# $\widehat{T}_{i}=N_{i} \bar{y}_{i}$
#
# Ce qui donne avec les valeurs numériques :
#
# $\begin{array}{l}
# \widehat{T_{1}}=40 \cdot 12=480 \\
# \widehat{T_{2}}=20 \cdot 8=160 \\
# \widehat{T_{3}}=60 \cdot 10=600 \\
# \widehat{T_{4}}=40 \cdot 12=480 \\
# \widehat{T_{5}}=48 \cdot 11=528 \\
# \end{array}$
#
# On estime la note totale dans le district par:
#
# $\begin{aligned}
# \widehat{T} &=\frac{M}{m} \sum_{i=1}^{m} \widehat{T}_{i} \\
# &=\frac{50}{5} \cdot 2248 \\
# &=22480
# \end{aligned}$
#
# 2. Le nombre estimé d'élèves est égal à
#
# $\begin{aligned}
# \hat{N} &=\frac{M}{m} \sum_{i=1}^{m} N_{i} \\
# &=\frac{50}{5} \cdot(40+20+60+40+48) \\
# &=2080
# \end{aligned}$
#
# 3. Si l'on sait que $N=2000$ alors
#
# $\begin{aligned}
# \widehat{\vec{Y}} &=\frac{1}{N} \cdot \widehat{T} \\
# &=\frac{1}{2000} \cdot 22480 \\
# &=11,24
# \end{aligned}$
#
# Par conséquent la moyenne observée sur l'échantillon de taille 50 est égale à
#
# $\bar{y}=\frac{1}{50} \cdot(10 \cdot 12+10 \cdot 18+10 \cdot 10+10 \cdot 12+10 \cdot 11)=10,6$
#
#
# 4. Calculons la variance de l'estimateur du total. On ne peut pas la calculer.Don on calculera une estimation de cette variance. Elle est égale à
#
# $\widehat{\operatorname{Var}}(\widehat{T})=M^{2}\left(1-f_{1}\right) \frac{s_{1}^{2}}{m}+\frac{M}{m} \sum_{i} N_{i}^{2}\left(1-f_{2, i}\right) \frac{s_{2, i}^{2}}{n_{i}}$
#
# où
#
# $s_{1}^{2}=\frac{1}{m-1} \sum_{i=1}^{m}\left(\widehat{T}_{i}-\frac{\widehat{T}}{M}\right)^{2}$
#
# qui est la variance observée entre les unités primaires et
#
# $s_{2, i}^{2}=\frac{1}{n_{i}-1} \sum_{j}\left(y_{i, j}-\bar{y}_{i}\right)^{2}$
#
# qui est la variance observée dans les unités secondaires.
#
# $s_{2, i}^{2}$ est donnée dans le tableau. Il ne reste plus qu'a calculer $s_{1}^{2}$
#
# $s_{1}^{2}=\frac{1}{4}\left[(480-449,6)^{2}+(160-449,6)^{2}+(600-449,6)^{2}+(480-449,6)^{2}+(528-449,6)^{2}\right]=28620,8$
#
# qui peut se calculer également grấce à la formule développée suivante
#
# $\frac{1}{m-1} \sum_{i=1}^{m} \widehat{T}_{i}^{2}-\frac{m}{m-1} \widehat{T}^{2}$
#
# Maintenant, on peut calculer le premier terme de l'estimation de la variance de l'estimateur du total qui vaut alors
#
# $M^{2}\left(1-f_{1}\right) \frac{s_{1}^{2}}{m}=50^{2} \cdot 0,9 \cdot \frac{28620,8}{5}=12879360$
#
# Maintenant en posant
#
# $V_{i}=N_{i}^{2}\left(1-f_{2, i}\right) \frac{s_{2, i}^{2}}{n_{i}}$
#
#
# on peut calculer le second terme de l'estimation de la variance de l'estimateur du total qui vaudra alors la somme des quantités suivantes pondérée par la quantité $M / m$
#
# $\begin{array}{l}
# V_{1}=40^{2} \cdot\left(1-\frac{10}{40}\right) \cdot \frac{1,5}{10}=180, \\
# V_{2}=24 \\
# V_{3}=480 \\
# V_{4}=156 \\
# V_{5}=364,8
# \end{array}$
#
# Ainsi en multilpliant par $M / m,$ on obtient que la quantité cherchée est égale à
#
# $\frac{M}{m} \sum_{i=1}^{5} V_{i}=\frac{50}{5} \cdot 1204,8=12048$
#
# Finalement, I'estimation de la variance de l'estimateur du total est égale à
#
# $\widehat{\operatorname{Var}}(\hat{T})=12879360+12048=12891408$
#
# On en déduit la variance de la moyenne qui est égale à
#
# $\begin{aligned}
# \widehat{\operatorname{Var}}(\bar{Y}) &=\frac{1}{N^{2}} \widehat{\operatorname{Var}}(\bar{T}) \\
# &=\frac{1}{(2000)^{2}} \cdot 12891408 \\
# &=3,22
# \end{aligned}$
#
# On obtient ainsi la précision qui est égale à
#
# $\pm 1,96 \sqrt{3,22}=3,5$
#
# et qui va nous permettre de calculer un intervalle de confiance de la moyenne, à $95 \%$ qui vaut
# $11,2 \pm 3,5$
#
# autrement dit la précision est très mauvaise. Cela est du à la grande dispersion des totaux.
#
# 5. Comparaison avec un sondage aleatoire simple à probabilites égales sur les mêmes données.
# On prend
#
# $\widehat{\bar{Y}}=\bar{y}=10,6, \quad n=50 \quad$ et $\quad N=2000$
#
# Donc le taux de sondage est égal à
#
# $f=\frac{50}{2000}=0,25$
#
# L'estimation de la variance de l'estimateur de la moyenne est égal à
#
# $\widehat{\operatorname{Var}}(\widehat{\bar{Y}})=(1-f) \frac{s^{2}}{n}$
#
# où $s^{2}$ est la variance corrigée de l'échantillon.
# Dans notre échantillon de taille $50,$ on a
# variance totale $=$ variance inter $+$ variance intra
# Calculons maintenant chaque terme qui compose la variance totale.
#
# $\begin{aligned}
# \text { variance inter } &=\frac{1}{50} \cdot\left(10 \cdot 12^{2}+10 \cdot 8^{2}+10 \cdot 10^{2}+10 \cdot 12^{2}+10 \cdot 11^{2}\right)-10,6^{2} \\
# &=2,24 \\
# \text { variance intra } &=\frac{1}{50} \cdot(10 \cdot \frac{9}{10} \cdot 1,5+10 \cdot \frac{9}{10} \cdot 1,2+10 \cdot \frac{9}{10} \cdot 1,6+10 \cdot \frac{9}{10} \cdot 1,3+10 \cdot \frac{9}{10} \cdot 2,0) \\
# &=1,368
# \end{aligned}$
#
# Donc la variance totale est égale à
#
# $2,24+1,368=3,608$
#
# et par conséquent la variance corrigé est égale à
#
# $s^{2}=\frac{50}{49} \cdot 3,608=3,68$
#
# On en déduit que
#
# $\widehat{\operatorname{Var}}(\widehat{\bar{Y}})=(1-0,25) \cdot \frac{3,68}{50}=0,07$
#
# La précision est égale à
#
# $\pm 1,96 \sqrt{0,07} \simeq \pm 0,52$
#
# D'où
#
# $\bar{Y}=10,6 \pm 0,52$
#
# Conclusion : La précision d'un sondage aleatoire simple à probabilites égales sans remise est supérieure à celle d'un sondage à plusieurs degrés, surtout que les classes sont peu homogènes générant une grande variance au $1^{\text {er }}$ degré.
#
#
#
# Une étude portant sur 25 voitures identiques indique une consommation moyenne de 8,5 litres aux $100 \mathrm{km}$ avec un écart type de 0.8 litre.
#
# a. Estimation ensembliste de la consommation moyenne de ce type de véhicule au seuil de $5 \%$
#
# Etant donné que la variance  est connue nous aurons l'interval de confiance suivant:
#
# $I C_{1-\alpha}(\mu)=\left[\bar{x}_{n}-q_{1-\alpha / 2} \frac{\sigma}{\sqrt{n}}, \bar{x}_{n}+q_{1-\alpha / 2} \frac{\sigma}{\sqrt{n}}\right]$
#
# où $\bar{x}_{n}$ représente la moyenne et $q_{1-\alpha / 2}$ le quantile d'ordre $1-\alpha / 2$
#
# Nous aurons donc:
#
# $I C_{1-\alpha}(\mu)=\left[8,5-1,96\frac{0,8}{\sqrt{25}} ;  8,5+1,96\frac{0,8}{\sqrt{25}}\right]$   d'ou
#
# $I C_{1-\alpha}(\mu)=\left[8,1864 ; 8,8136\right]$
#
#
# b) Le nombre minimal d'observations auxquelles on devrait procéder pour connaitre la consommation moyenne à plus ou moins 2 décilitres près (au plus) aux seuils de $5 \%$ et de $1 \% ?$
#
# - Au seuil de $5 \%$ :
#
# $q_{1-\alpha / 2} \frac{\sigma}{\sqrt{n}}$ = 0,2 implique que
#
# $1,96\frac{0,8}{\sqrt{n}}$ = 0,2 implique que
#
# n= ${\frac{{1,568}^2}{{0,2}^2}} $
#
# d'ou n= 61
#
# - Au seuil de $1 \%$ :
#
# $q_{1-\alpha / 2} \frac{\sigma}{\sqrt{n}}$ = 0,2 implique que
#
# $2,5758\frac{0,8}{\sqrt{n}}$ = 0,2 implique que
#
# n= ${\frac{{2,06064}^2}{{0,2}^2}} $
#
# d'ou n= 106

# %% [markdown]
# # Exercice 4
#
# Un verificateur est charge de contróler la qualite d'un certain nombre d'enregistrements comptables. L'hypothèse est faite sur le vu de vérifications antérieures, d'un niveau d'acceptation $\mathrm{p}=0,05$
#
# a- On prévoit de contrôler $n=200$ enregistrements. Le maximum d'erreurs qui peut etre accepter dans cet échantillon sans remettre en cause le niveau d'acceptation 0,05.
#
# Soit $E$ le nombre d'erreurs maximum
#
# $\frac{E}{n}  = 0,05$ implique que  $E  = 0,05n$  implique que $E  = 0,05 . 200$  d'où  $E  = 10$
#
# Avec un nombre d'enregistrement égale à 200, le nombre maximum d'erreurs à ne pas dépasser est de 10
#
# -Avec $n=400$
#
# $E  = 0,05 . 400$  donc  $E  = 20$
#
# Avec un nombre d'enregistrement égale à 400, le nombre maximum d'erreurs à ne pas dépasser est de 20
#
# -Avec $n=600$
#
# $E = 0,05 . 600$  donc  $E  = 30$
#
# Avec un nombre d'enregistrement égale à 600, le nombre maximum d'erreurs à ne pas dépasser est de 30
#
# -Avec $n=1000$
#
# $E  = 0,05 . 1000$  donc  $E  = 50$
#
# Avec un nombre d'enregistrement égale à 1000, le nombre maximum d'erreurs à ne pas dépasser est de 50
#
# 2- Avec le méme niveau d'acceptation, on a fait un sondage sur $n=400$ enregistrements. On a constaté 7 erreurs. Le controle est poursuivi. Le nombre d'enregistrements supplémentaires à examiner en tolérant, au cours de ce controle 4 nouvelles erreurs, pour que l'hypothèse d'un niveau d'acceptation de $5 \%$ puisse être raisonnablement retenue.
#
#
# Soit n2 le nnombre d'enregistrements supplémentaires.
#
# Lors du premier sondage avec n=400 et E(Nombre d'érreurs) = 7 on a comme niveau d'acceptation
#
# $\frac{E}{n2}$= $\frac{7}{400}$= 0,0175
#
# Il reste donc un niveau d'acceptation supplémentaire de 0,0325 pour atteindre le niveau d'acceptation raisonable de 0,05
# donc pour que ce niveau soit tolérer, il faut que
#
#  $\frac{4}{n2}$= 0,0325 implique que n2= $\frac{4}{0,0325}$ donc n2= 123

# %%
# calcul de l'exercice 5
print('les calculs de lexo 5')
import numpy as np
import pandas as pd

N = np.array( [500,300,150,100,10])
n =np.array( [130,80,60,25,5]) 
yh =  np.array( [5,12,30,150,600])
sh2 =np.array( [1.5,4,8,100,2500]) 

exo5 = {'N': N,
        'n': n,
         'yh': yh,
        'sh2': sh2 
         }
exo5 = pd.DataFrame(exo5)

pop = sum(exo5['N']) # la taille N de lapouplation 
echan =  sum(exo5['n']) # la taille n de l'echantillon


print('\nvoici notre tableau des resultats donnees par lexercice : ')
print('\n',exo5)
print('\n1 - Donnons une estimation du chiffre daffaire moyenne avec un intervalle de confiance')

print('\ncalculons lestimateur de la moyenne : ')
u_chapo = 0  #estimateur de la moyenne
u_chapo = ( 1/ pop ) * ( sum ( exo5['N'] * exo5['yh'] ))
print(u_chapo)

print('\ncalculons la variance de lestimateur de la moyenne : ')
v_u_chapo = 0 # la variance de l'estimateur de la moyenne
v_u_chapo = ( 1/ (pop**2) ) * (sum (exo5['N'] * (((exo5['N']-exo5['n'])/exo5['n']) * exo5['sh2']) ))
print( v_u_chapo)

print('\nlintervalle de confiance a 95% de confiance est : ')
print (' [', u_chapo - (1.96 * (np.sqrt(v_u_chapo))),' , ',u_chapo + (1.96 * (np.sqrt(v_u_chapo))),']' )


print('\n 2 - En conservant toujours la meme taille globale dechantillon les effectifs a considerer pour chaque strate sont:'  )
print('\n 2 - (a) Pour chaque strate leffectif dechantillon selon la proportion proportionnelle se presente comme suit : ' )
propprtionelle = []
allo_pro = 0 # l'allocation proportionelle 
allo_pro = echan * (exo5['N'] / pop)
for i in range (5):
    propprtionelle.append(round(allo_pro[i], 0))
    print('n',i+1,'=',round(allo_pro[i], 0))

print('\n 2 - (b) Pour chaque strate leffectif dechantillon selon la proportion optimale se presente comme suite : ' )
allo_opt = 0 # l'allocation optimale
for i in range (5) :
    allo_opt = echan * (exo5['N'][i] * np.sqrt(exo5['sh2'][i])) / (sum(exo5['N'] * np.sqrt(exo5['sh2'])))
    print('n',i+1,'=',round(allo_opt, 0))
    
print('\nNous avons constater que pour n5 la taille depasse le nombre dentreprise de la strate')
print('Nous avons avons pris 10 pour la strate et refaire les calcul avec la taille de dechantillon 290')
for i in range (4) :
    allo_opt = (echan - 10) * (exo5['N'][i] * np.sqrt(exo5['sh2'][i])) / (sum(exo5['N'][:4] * np.sqrt(exo5['sh2'][:4])))
    print('n',i+1,'=',round(allo_opt, 0))
print('n',5,'=', 10)


print('\nNous remarquons encore que dans n5 la taille depasse le nombre dentreprise de la strate')
print('Nous avons avons pris 100 pour la strate et refaire les calcul avec la taille de dechantillon 190')
optimale = [] 
for i in range (3) :
    allo_opt = (echan - 110) * (exo5['N'][i] * np.sqrt(exo5['sh2'][i])) / (sum(exo5['N'][:3] * np.sqrt(exo5['sh2'][:3])))
    optimale.append(round(allo_opt, 0))  
    print('n',i+1,'=',round(allo_opt, 0))
print('n',4,'=', 100)
print('n',5,'=', 10)
optimale.append(100)    
optimale.append(10)

      
print('\n 3 - Ensupposantinhangées les variances dans les strates, calculons les variances')


print('\n a - la variance de lestimateur pour le plan avec allocation proptionnelle : ')

v_u_chapo_prop = ( 1/ (pop**2) ) * (sum (exo5['N'] * (((exo5['N']-propprtionelle)/propprtionelle) * exo5['sh2']) ))
print(v_u_chapo_prop)


print('\n b - la variance de lestimateur pour le plan avec allocation optimale : ')

v_u_chapo_opt = ( 1/ (pop**2) ) * (sum (exo5['N'] * (((exo5['N']-optimale)/optimale) * exo5['sh2']) ))
print(v_u_chapo_opt)
# Out:
# les calculs de lexo 5
#
# voici notre tableau des resultats donnees par lexercice :
#
#       N    n   yh     sh2
# 0  500  130    5     1.5
# 1  300   80   12     4.0
# 2  150   60   30     8.0
# 3  100   25  150   100.0
# 4   10    5  600  2500.0
#
# 1 - Donnons une estimation du chiffre daffaire moyenne avec un intervalle de confiance
#
# calculons lestimateur de la moyenne :
# 29.81132075471698
#
# calculons la variance de lestimateur de la moyenne :
# 0.05538858613796314
#
# lintervalle de confiance a 95% de confiance est :
#  [ 29.350039070160136  ,  30.272602439273825 ]
#
#  2 - En conservant toujours la meme taille globale dechantillon les effectifs a considerer pour chaque strate sont:
#
#  2 - (a) Pour chaque strate leffectif dechantillon selon la proportion proportionnelle se presente comme suit :
# n 1 = 142.0
# n 2 = 85.0
# n 3 = 42.0
# n 4 = 28.0
# n 5 = 3.0
#
#  2 - (b) Pour chaque strate leffectif dechantillon selon la proportion optimale se presente comme suite :
# ...
